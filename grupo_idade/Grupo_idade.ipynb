# %%
import csv
import pandas as pd

# %%
df = pd.read_csv('IBGE-grupo_idade.csv')

# %%
print(df)
# Out:
#       ano      sexo      grupo_idade    populacao
# 0    2012     Total            Total  197721000.0
# 1    2012     Total       0 a 4 anos   13381000.0
# 2    2012     Total      5 a 13 anos   27795000.0
# 3    2012     Total       5 a 9 anos   14412000.0
# 4    2012     Total     10 a 13 anos   13384000.0
# ..    ...       ...              ...          ...
# 403  2019  Mulheres     40 a 49 anos   15176000.0
# 404  2019  Mulheres     50 a 59 anos   13802000.0
# 405  2019  Mulheres  60 anos ou mais   18404000.0
# 406  2019  Mulheres     60 a 64 anos    5580000.0
# 407  2019  Mulheres  65 anos ou mais   12824000.0
#
# [408 rows x 4 columns]

# %%
df_filtered1 = df[df.sexo.str.contains(
    "Total") & df.grupo_idade.str.contains("Total")]
df_filtered2 = df[df.sexo.str.contains(
    "Total") & df.grupo_idade.str.contains("0 a 4 anos")]
df_filtered3 = df[df.sexo.str.contains(
    "Total") & df.grupo_idade.str.contains("5 a 13 anos")]
df_filtered4 = df[df.sexo.str.contains(
    "Total") & df.grupo_idade.str.contains("5 a 9 anos")]
df_filtered5 = df[df.sexo.str.contains(
    "Total") & df.grupo_idade.str.contains("10 a 13 anos")]
df_filtered6 = df[df.sexo.str.contains(
    "Total") & df.grupo_idade.str.contains("14 a 17 anos")]
df_filtered7 = df[df.sexo.str.contains(
    "Total") & df.grupo_idade.str.contains("14 a 15 anos")]
df_filtered8 = df[df.sexo.str.contains(
    "Total") & df.grupo_idade.str.contains("16 a 17 anos")]
df_filtered9 = df[df.sexo.str.contains(
    "Total") & df.grupo_idade.str.contains("18 a 19 anos")]
df_filtered10 = df[df.sexo.str.contains(
    "Total") & df.grupo_idade.str.contains("20 a 24 anos")]
df_filtered11 = df[df.sexo.str.contains(
    "Total") & df.grupo_idade.str.contains("25 a 29 anos")]
df_filtered12 = df[df.sexo.str.contains(
    "Total") & df.grupo_idade.str.contains("30 a 39 anos")]
df_filtered13 = df[df.sexo.str.contains(
    "Total") & df.grupo_idade.str.contains("40 a 49 anos")]
df_filtered14 = df[df.sexo.str.contains(
    "Total") & df.grupo_idade.str.contains("50 a 59 anos")]
df_filtered15 = df[df.sexo.str.contains(
    "Total") & df.grupo_idade.str.contains("60 anos ou mais")]
df_filtered16 = df[df.sexo.str.contains(
    "Total") & df.grupo_idade.str.contains("60 a 64 anos")]
df_filtered17 = df[df.sexo.str.contains(
    "Total") & df.grupo_idade.str.contains("65 anos ou mais")]

df_filtered18 = df[df.sexo.str.contains(
    "Homens") & df.grupo_idade.str.contains("Total")]
df_filtered19 = df[df.sexo.str.contains(
    "Homens") & df.grupo_idade.str.contains("0 a 4 anos")]
df_filtered20 = df[df.sexo.str.contains(
    "Homens") & df.grupo_idade.str.contains("5 a 13 anos")]
df_filtered21 = df[df.sexo.str.contains(
    "Homens") & df.grupo_idade.str.contains("5 a 9 anos")]
df_filtered22 = df[df.sexo.str.contains(
    "Homens") & df.grupo_idade.str.contains("10 a 13 anos")]
df_filtered23 = df[df.sexo.str.contains(
    "Homens") & df.grupo_idade.str.contains("14 a 17 anos")]
df_filtered24 = df[df.sexo.str.contains(
    "Homens") & df.grupo_idade.str.contains("14 a 15 anos")]
df_filtered25 = df[df.sexo.str.contains(
    "Homens") & df.grupo_idade.str.contains("16 a 17 anos")]
df_filtered26 = df[df.sexo.str.contains(
    "Homens") & df.grupo_idade.str.contains("18 a 19 anos")]
df_filtered27 = df[df.sexo.str.contains(
    "Homens") & df.grupo_idade.str.contains("20 a 24 anos")]
df_filtered28 = df[df.sexo.str.contains(
    "Homens") & df.grupo_idade.str.contains("25 a 29 anos")]
df_filtered29 = df[df.sexo.str.contains(
    "Homens") & df.grupo_idade.str.contains("30 a 39 anos")]
df_filtered30 = df[df.sexo.str.contains(
    "Homens") & df.grupo_idade.str.contains("40 a 49 anos")]
df_filtered31 = df[df.sexo.str.contains(
    "Homens") & df.grupo_idade.str.contains("50 a 59 anos")]
df_filtered32 = df[df.sexo.str.contains(
    "Homens") & df.grupo_idade.str.contains("60 anos ou mais")]
df_filtered33 = df[df.sexo.str.contains(
    "Homens") & df.grupo_idade.str.contains("60 a 64 anos")]
df_filtered34 = df[df.sexo.str.contains(
    "Homens") & df.grupo_idade.str.contains("65 anos ou mais")]

df_filtered35 = df[df.sexo.str.contains(
    "Mulheres") & df.grupo_idade.str.contains("Total")]
df_filtered36 = df[df.sexo.str.contains(
    "Mulheres") & df.grupo_idade.str.contains("0 a 4 anos")]
df_filtered37 = df[df.sexo.str.contains(
    "Mulheres") & df.grupo_idade.str.contains("5 a 13 anos")]
df_filtered38 = df[df.sexo.str.contains(
    "Mulheres") & df.grupo_idade.str.contains("5 a 9 anos")]
df_filtered39 = df[df.sexo.str.contains(
    "Mulheres") & df.grupo_idade.str.contains("10 a 13 anos")]
df_filtered40 = df[df.sexo.str.contains(
    "Mulheres") & df.grupo_idade.str.contains("14 a 17 anos")]
df_filtered41 = df[df.sexo.str.contains(
    "Mulheres") & df.grupo_idade.str.contains("14 a 15 anos")]
df_filtered42 = df[df.sexo.str.contains(
    "Mulheres") & df.grupo_idade.str.contains("16 a 17 anos")]
df_filtered43 = df[df.sexo.str.contains(
    "Mulheres") & df.grupo_idade.str.contains("18 a 19 anos")]
df_filtered44 = df[df.sexo.str.contains(
    "Mulheres") & df.grupo_idade.str.contains("20 a 24 anos")]
df_filtered45 = df[df.sexo.str.contains(
    "Mulheres") & df.grupo_idade.str.contains("25 a 29 anos")]
df_filtered46 = df[df.sexo.str.contains(
    "Mulheres") & df.grupo_idade.str.contains("30 a 39 anos")]
df_filtered47 = df[df.sexo.str.contains(
    "Mulheres") & df.grupo_idade.str.contains("40 a 49 anos")]
df_filtered48 = df[df.sexo.str.contains(
    "Mulheres") & df.grupo_idade.str.contains("50 a 59 anos")]
df_filtered49 = df[df.sexo.str.contains(
    "Mulheres") & df.grupo_idade.str.contains("60 anos ou mais")]
df_filtered50 = df[df.sexo.str.contains(
    "Mulheres") & df.grupo_idade.str.contains("60 a 64 anos")]
df_filtered51 = df[df.sexo.str.contains(
    "Mulheres") & df.grupo_idade.str.contains("65 anos ou mais")]

# %%
df_filtered1 = df_filtered1.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered2 = df_filtered2.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered3 = df_filtered3.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered4 = df_filtered4.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered5 = df_filtered5.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered6 = df_filtered6.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered7 = df_filtered7.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered8 = df_filtered8.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered9 = df_filtered9.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered10 = df_filtered10.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered11 = df_filtered11.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered12 = df_filtered12.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered13 = df_filtered13.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered14 = df_filtered14.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered15 = df_filtered15.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered16 = df_filtered16.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered17 = df_filtered17.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered18 = df_filtered18.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered19 = df_filtered19.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered20 = df_filtered20.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered21 = df_filtered21.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered22 = df_filtered22.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered23 = df_filtered23.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered24 = df_filtered24.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered25 = df_filtered25.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered26 = df_filtered26.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered27 = df_filtered27.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered28 = df_filtered28.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered29 = df_filtered29.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered30 = df_filtered30.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered31 = df_filtered31.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered32 = df_filtered32.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered33 = df_filtered33.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered34 = df_filtered34.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered35 = df_filtered35.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered36 = df_filtered36.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered37 = df_filtered37.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered38 = df_filtered38.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered39 = df_filtered39.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered40 = df_filtered40.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered41 = df_filtered41.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered42 = df_filtered42.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered43 = df_filtered43.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered44 = df_filtered44.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered45 = df_filtered45.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered46 = df_filtered46.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered47 = df_filtered47.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered48 = df_filtered48.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered49 = df_filtered49.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered50 = df_filtered50.drop(axis=1, columns=['sexo', 'grupo_idade'])
df_filtered51 = df_filtered51.drop(axis=1, columns=['sexo', 'grupo_idade'])

# %%
df_merged = pd.merge(df_filtered1, df_filtered2, how='outer', on=['ano'])
df_merged = df_merged.rename(columns={'populacao_x': 'pop_total', 'populacao_y': '0 a 4 anos'})

df_merged = pd.merge(df_merged, df_filtered3,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': '5 a 13 anos'})

df_merged = pd.merge(df_merged, df_filtered4,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': '5 a 9 anos'})

df_merged = pd.merge(df_merged, df_filtered5,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': '10 a 13 anos'})

df_merged = pd.merge(df_merged, df_filtered6,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': '14 a 17 anos'})

df_merged = pd.merge(df_merged, df_filtered7,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': '14 a 15 anos'})

df_merged = pd.merge(df_merged, df_filtered8,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': '16 a 17 anos'})

df_merged = pd.merge(df_merged, df_filtered9,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': '18 a 19 anos'})

df_merged = pd.merge(df_merged, df_filtered10,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': '20 a 24 anos'})

df_merged = pd.merge(df_merged, df_filtered11,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': '25 a 29 anos'})

df_merged = pd.merge(df_merged, df_filtered12,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': '30 a 39 anos'})

df_merged = pd.merge(df_merged, df_filtered13,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': '40 a 49 anos'})

df_merged = pd.merge(df_merged, df_filtered14,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': '50 a 59 anos'})

df_merged = pd.merge(df_merged, df_filtered15,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': '60 anos ou mais'})

df_merged = pd.merge(df_merged, df_filtered16,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': '60 a 64 anos'})

df_merged = pd.merge(df_merged, df_filtered17,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': '65 anos ou mais'})

df_merged = pd.merge(df_merged, df_filtered18,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Homens total'})

df_merged = pd.merge(df_merged, df_filtered19,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Homens de 0 a 4 anos'})

df_merged = pd.merge(df_merged, df_filtered20,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Homens de 5 a 13 anos'})

df_merged = pd.merge(df_merged, df_filtered21,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Homens de 5 a 9 anos'})

df_merged = pd.merge(df_merged, df_filtered22,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Homens de 10 a 13 anos'})

df_merged = pd.merge(df_merged, df_filtered23,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Homens de 14 a 17 anos'})

df_merged = pd.merge(df_merged, df_filtered24,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Homens de 14 a 15 anos'})

df_merged = pd.merge(df_merged, df_filtered25,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Homens de 16 a 17 anos'})

df_merged = pd.merge(df_merged, df_filtered26,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Homens de 18 a 19 anos'})

df_merged = pd.merge(df_merged, df_filtered27,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Homens de 20 a 24 anos'})

df_merged = pd.merge(df_merged, df_filtered28,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Homens de 25 a 29 anos'})

df_merged = pd.merge(df_merged, df_filtered29,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Homens de 30 a 39 anos'})

df_merged = pd.merge(df_merged, df_filtered30,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Homens de 40 a 49 anos'})

df_merged = pd.merge(df_merged, df_filtered31,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Homens de 50 a 59 anos'})

df_merged = pd.merge(df_merged, df_filtered32,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Homens de 60 anos ou mais'})

df_merged = pd.merge(df_merged, df_filtered33,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Homens de 60 a 64 anos'})

df_merged = pd.merge(df_merged, df_filtered34,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Homens de 65 anos ou mais'})

df_merged = pd.merge(df_merged, df_filtered35,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Mulheres total'})

df_merged = pd.merge(df_merged, df_filtered36,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Mulheres de 0 a 4 anos'})

df_merged = pd.merge(df_merged, df_filtered37,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Mulheres de 5 a 13 anos'})

df_merged = pd.merge(df_merged, df_filtered38,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Mulheres de 5 a 9 anos'})

df_merged = pd.merge(df_merged, df_filtered39,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Mulheres de 10 a 13 anos'})

df_merged = pd.merge(df_merged, df_filtered40,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Mulheres de 14 a 17 anos'})

df_merged = pd.merge(df_merged, df_filtered41,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Mulheres de 14 a 15 anos'})

df_merged = pd.merge(df_merged, df_filtered42,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Mulheres de 16 a 17 anos'})

df_merged = pd.merge(df_merged, df_filtered43,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Mulheres de 18 a 19 anos'})

df_merged = pd.merge(df_merged, df_filtered44,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Mulheres de 20 a 24 anos'})

df_merged = pd.merge(df_merged, df_filtered45,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Mulheres de 25 a 29 anos'})

df_merged = pd.merge(df_merged, df_filtered46,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Mulheres de 30 a 39 anos'})

df_merged = pd.merge(df_merged, df_filtered47,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Mulheres de 40 a 49 anos'})

df_merged = pd.merge(df_merged, df_filtered48,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Mulheres de 50 a 59 anos'})

df_merged = pd.merge(df_merged, df_filtered49,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Mulheres de 60 anos ou mais'})

df_merged = pd.merge(df_merged, df_filtered50,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Mulheres de 60 a 64 anos'})

df_merged = pd.merge(df_merged, df_filtered51,
                     how='outer', on=['ano'])
df_merged = df_merged.rename(
    columns={'populacao': 'Mulheres de 65 anos ou mais'})

print(df_merged)
# Out:
#     ano    pop_total  0 a 4 anos  5 a 13 anos  5 a 9 anos  10 a 13 anos  \
# 0  2012  197721000.0  13381000.0   27795000.0  14412000.0    13384000.0
# 1  2013  199402000.0  13487000.0   27548000.0  14294000.0    13255000.0
# 2  2014  201108000.0  13060000.0   26749000.0  14096000.0    12653000.0
# 3  2015  202859000.0  13046000.0   26371000.0  14075000.0    12296000.0
# 4  2016  204532000.0  12912000.0   25687000.0  13576000.0    12111000.0
# 5  2017  206172000.0  13080000.0   25616000.0  13697000.0    11919000.0
# 6  2018  207853000.0  13124000.0   25478000.0  13645000.0    11832000.0
# 7  2019  209496000.0  13072000.0   25337000.0  13785000.0    11552000.0
#
#    14 a 17 anos  14 a 15 anos  16 a 17 anos  18 a 19 anos  ...  \
# 0    14237000.0     7109000.0     7128000.0     6706000.0  ...
# 1    13981000.0     6945000.0     7036000.0     6866000.0  ...
# 2    14147000.0     7127000.0     7020000.0     6770000.0  ...
# 3    13878000.0     6999000.0     6878000.0     6789000.0  ...
# ...

# %%
df_merged.to_csv('./pnadc_grupo_idade.csv', index = False)
